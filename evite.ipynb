# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statistics

# %% [markdown]
# # Establish Database Connection

# %%
import psycopg2

conn =psycopg2.connect("dbname=postgres user=postgres password=password host=35.236.196.171")

# %%
df = pd.DataFrame()
for chunk in pd.read_sql("SELECT * from events ORDER by random() LIMIT 1300000", con=conn, chunksize=1000):
    df = df.append(chunk)

# %% [markdown]
# # Data Cleaning

# %%
def clean_zip(x):
    if x == float('nan') or len(str(x)) == 5:
        return x
    elif len(str(x)) == 10:
        return x[:-5]
    else:
        return False
      
zip_seq = df["zip"].apply(clean_zip) #non-U.S. zip as False
df = df[zip_seq != False]

# %% [markdown]
# # Features

# %% [markdown]
# ## List of Features

# %%
#dates
dates = df['event_date']
#print(dates)

# %%
#rsvp %
yes_percent = df["rsvp_yes"]/df["guests"]
no_percent = df["rsvp_no"]/df["guests"]
maybe_percent = df["rsvp_maybe"]/df["guests"]
undecided_percent = df["rsvp_undecided"]/df["guests"]

# %%
# time of the day
times = [date.to_pydatetime(date).hour for date in dates]
day_part = ['Morning' if (time >= 0 and time <= 11)
            else 'Afternoon' if (time >= 12 and time <= 17)
            else 'Evening' if (time >= 8 and time <= 23)
            else 'Unknown'
            for time in times]
#print(day_part)

# %%
#seasons
months = [date.to_pydatetime(date).month for date in dates]
seasons = [(month%12 + 3)//3 for month in months]
seasons_text = ['Winter' if s == 1 
                else 'Spring' if s == 2 
                else 'Summer' if s == 3 
                else 'Fall' if s == 4 
                else 'Unknown' for s in seasons]
#print(seasons_text)

# %%
#create event diff
created_dates = df['created_date']
created_dates = [create_date.to_pydatetime(create_date) for create_date in created_dates]
event_dates = df['event_date']
event_dates = [event_date.to_pydatetime(event_date) for event_date in event_dates]
create_event_diff = [event - created for event, created in zip(event_dates, created_dates)]
create_event_diff = [td.days for td in create_event_diff]
#print(create_event_diff)

# %%
#mail event diff
mail_dates = df['sent_on']
mail_dates = [mail_date.to_pydatetime(mail_date) for mail_date in mail_dates]
mail_event_diff = [event - mail for event, mail in zip(event_dates, mail_dates)]
mail_event_diff = [td.days for td in mail_event_diff]
#print(mail_event_diff)

# %%
#create mail diff
create_mail_diff = [created - mail for created, mail in zip(created_dates, mail_dates)]
create_mail_diff = [td.days for td in create_mail_diff]

# %%
#zip-income table
from uszipcode import SearchEngine,Zipcode
search = SearchEngine(simple_zipcode=True)
result = search.by_median_household_income(returns=0)
#to specify range,use lower/upper = ""
#result = search.by_median_household_income(lower=100000,upper=150000,returns=0)
#output to lists
zip_list = []
income_list = []

for zipcode in result:
    zip_list.append(zipcode.to_dict()['zipcode'])
    income_list.append(zipcode.to_dict()['median_household_income'])
    #rent_list.append(zipcode.to_dict()['monthly_rent_including_utilities_3plus_b'])
#convert to df
zip_df = pd.DataFrame({
    'zipcode':zip_list,
    'median_household_income':income_list
})

# %%
df.head()
# Out:
#    event_id  host_id        event_type     event_category correspondence  \
# 0   1213613  1012281  birthday_forkids  Birthday for Kids          False
# 1   8891192  4552157     save_the_date      Save the Date          False
# 2   6811809  1302872     holiday_party      Holiday Party          False
# 3    371264   344035         halloween          Halloween          False
# 4   3671638  2487986  birthday_forkids  Birthday for Kids          False
#
#   event_category_group seasonal          event_date  \
# 0             Birthday    False 2018-11-04 13:00:00
# 1   Wedding or related    False 2017-02-19 14:00:00
# 2      Winter Holidays     True 2015-12-12 18:00:00
# 3            Halloween     True 2018-10-27 18:00:00
# 4             Birthday    False 2015-12-05 14:05:00
#
#                      sent_on               created_date  \
# 0 2018-10-11 16:07:15.000000 2018-10-01 20:00:26.178694
# 1 2017-01-30 18:34:02.000000 2017-01-29 03:41:08.706280
# 2 2015-11-28 19:02:21.684760 2015-11-27 15:20:11.788110
# 3 2018-10-06 18:23:01.000000 2018-10-05 01:22:06.125188
# 4 2015-11-07 23:11:27.000000 2015-11-07 22:52:29.489110
#
#                        location    zip premium_vs_free         template_name  \
# 0                          Home  80138            Free  newchalkballoons_uyo
# 1  Church/Religious Institution  32561            Free           eaglescouts
# 2                  Unidentified  60540            Free        ohwhatberryfun
# 3                          Home  60439            Free  halloweenspiders_ani
# 4            Recreation Centers  80016            Free           oceansoffun
#
#    guests  rsvp_yes  rsvp_no  rsvp_maybe  rsvp_undecided
# 0      19        11        3           1               4
# 1      50         9        3           0              38
# 2      59        24       19           3              13
# 3      51        16       17           3              15
# 4      18         8        3           1               6

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# ### Correlation

# %%
# Out:
# ['Fall',
#  'Winter',
#  'Winter',
#  'Fall',
#  'Winter',
#  'Fall',
#  'Winter',
#  'Fall',
#  'Spring',
#  'Fall',
#  'Fall',
#  'Winter',
#  'Spring',
#  'Winter',
#  'Fall',
#  'Fall',
#  'Winter',
#  'Fall',
#  'Fall',
#  'Winter',
#  'Winter',
#  'Fall',
#  'Summer',
#  'Winter',
#  'Winter',
#  'Winter',
#  'Fall',
#  'Winter',
#  'Spring',
#  'Winter',
#  'Winter',
#  'Spring',
#  'Summer',
#  'Fall',
#  'Summer',
#  'Winter',
#  'Summer',
#  'Summer',
#  'Fall',
#  'Spring',
#  'Spring',
#  'Summer',
#  'Fall',
#  'Summer',
#  'Winter',
#  'Fall',
#  'Fall',
#  'Spring',
#  'Summer',
#  'Fall',
#  'Fall',
#  'Spring',
#  'Fall',
#  'Summer',
#  'Winter',
#  'Summer',
#  'Winter',
#  'Spring',
#  'Winter',
#  'Spring',
#  'Fall',
#  'Summer',
#  'Summer',
#  'Winter',
#  'Spring',
#  'Summer',
#  'Winter',
#  'Fall',
#  'Winter',
#  'Summer',
#  'Spring',
#  'Fall',
#  'Summer',
#  'Spring',
#  'Fall',
#  'Fall',
#  'Summer',
#  'Summer',
#  'Fall',
#  'Fall',
#  'Fall',
#  'Winter',
#  'Fall',
#  'Summer',
#  'Winter',
#  'Winter',
#  'Fall',
#  'Spring',
#  'Winter',
#  'Fall',
#  'Fall',
#  'Spring',
#  'Spring',
#  'Fall',
#  'Winter',
#  'Spring',
#  'Winter',
#  'Winter',
#  'Summer',
#  'Spring',
#  'Winter',
#  'Spring',
#  'Fall',
#  'Summer',
#  'Spring',
#  'Summer',
#  'Spring',
#  'Winter',
#  'Winter',
#  'Summer',
#  'Winter',
#  'Summer',
#  'Fall',
#  'Winter',
#  'Fall',
#  'Summer',
#  'Summer',
#  'Spring',
#  'Winter',
#  'Summer',
#  'Winter',
#  'Winter',
#  'Spring',
#  'Spring',
#  'Spring',
#  'Fall',
#  'Winter',
#  'Fall',
#  'Winter',
#  'Spring',
#  'Winter',
#  'Winter',
#  'Fall',
#  'Spring',
#  'Spring',
#  'Fall',
#  'Spring',
#  'Summer',
#  'Winter',
#  'Fall',
#  'Summer',
#  'Spring',
#  'Spring',
#  'Fall',
#  'Spring',
#  'Winter',
#  'Summer',
#  'Summer',
#  'Winter',
#  'Summer',
#  'Spring',
#  'Spring',
#  'Spring',
#  'Spring',
#  'Spring',
#  'Spring',
#  'Summer',
#  'Fall',
#  'Winter',
#  'Spring',
#  'Winter',
#  'Spring',
#  'Summer',
#  'Winter',
#  'Fall',
#  'Fall',
#  'Winter',
#  'Summer',
#  'Summer',
#  'Fall',
#  'Winter',
#  'Fall',
#  'Fall',
#  'Winter',
#  'Summer',
#  'Winter',
#  'Summer',
#  'Fall',
#  'Summer',
#  'Spring',
#  'Summer',
#  'Summer',
#  'Spring',
#  'Fall',
#  'Spring',
#  'Summer',
#  'Fall',
#  'Fall',
#  'Winter',
#  'Summer',
#  'Spring',
#  'Winter',
#  'Fall',
#  'Fall',
#  'Fall',
#  'Winter',
#  'Summer',
#  'Spring',
#  'Summer',
#  'Spring',
#  'Spring',
#  'Fall',
#  'Spring',
#  'Winter',
#  'Summer',
#  'Winter',
#  'Fall',
#  'Spring',
#  'Summer',
#  'Spring',
#  'Spring',
#  'Fall',
#  'Fall',
#  'Fall',
#  'Spring',
#  'Summer',
#  'Winter',
#  'Fall',
#  'Spring',
#  'Winter',
#  'Fall',
#  'Winter',
#  'Summer',
#  'Winter',
#  'Fall',
#  'Winter',
#  'Summer',
#  'Winter',
#  'Spring',
#  'Fall',
#  'Winter',
#  'Summer',
#  'Summer',
#  'Fall',
#  'Summer',
#  'Spring',
#  'Summer',
#  'Spring',
#  'Fall',
#  'Winter',
#  'Winter',
#  'Winter',
#  'Winter',
#  'Winter',
#  'Summer',
#  'Winter',
#  'Winter',
#  'Fall',
#  'Fall',
#  'Summer',
#  'Spring',
#  'Summer',
#  'Fall',
#  'Winter',
#  'Summer',
#  'Fall',
#  'Summer',
#  'Winter',
#  'Summer',
#  'Spring',
#  'Winter',
#  'Winter',
#  'Winter',
#  'Spring',
#  'Fall',
#  'Winter',
#  'Fall',
#  'Fall',
#  'Winter',
#  'Spring',
#  'Fall',
#  'Winter',
#  'Fall',
#  'Spring',
#  'Winter',
#  'Winter',
#  'Fall',
#  'Fall',
#  'Fall',
#  'Fall',
#  'Summer',
#  'Winter',
#  'Spring',
#  'Fall',
#  'Spring',
#  'Winter',
#  'Winter',
#  'Spring',
#  'Fall',
#  'Spring',
#  'Spring',
#  'Winter',
#  'Spring',
#  'Summer',
#  'Winter',
#  'Fall',
#  'Winter',
#  'Summer',
#  'Fall',
#  'Fall',
#  'Winter',
#  'Fall',
#  'Fall',
#  'Winter',
#  'Fall',
#  'Winter',
#  'Winter',
#  'Winter',
#  'Fall',
#  'Spring',
#  'Spring',
#  'Spring',
#  'Winter',
#  'Fall',
#  'Summer',
#  'Summer',
#  'Summer',
#  'Spring',
#  'Fall',
#  'Fall',
#  'Spring',
#  'Fall',
#  'Summer',
#  'Spring',
#  'Fall',
#  'Winter',
#  'Spring',
#  'Summer',
#  'Winter',
#  'Fall',
#  'Summer',
#  'Spring',
#  'Spring',
#  'Winter',
#  'Fall',
#  'Spring',
#  'Winter',
#  'Summer',
#  'Winter',
#  'Winter',
#  'Spring',
#  'Winter',
#  'Fall',
#  'Fall',
#  'Winter',
#  'Winter',
#  'Fall',
#  'Summer',
#  'Summer',
#  'Winter',
#  'Winter',
#  'Winter',
#  'Winter',
#  'Fall',
#  'Summer',
#  'Summer',
#  'Summer',
#  'Spring',
#  'Summer',
#  'Summer',
#  'Summer',
#  'Spring',
#  'Summer',
#  'Winter',
#  'Summer',
#  'Spring',
#  'Fall',
#  'Fall',
#  'Summer',
#  'Spring',
#  'Summer',
#  'Summer',
#  'Fall',
#  'Fall',
#  'Winter',
#  'Fall',
#  'Fall',
#  'Spring',
#  'Summer',
#  'Fall',
#  'Winter',
#  'Winter',
#  'Summer',
#  'Fall',
#  'Fall',
#  'Summer',
#  'Winter',
#  'Spring',
#  'Fall',
#  'Winter',
#  'Summer',
#  'Winter',
#  'Winter',
#  'Fall',
#  'Winter',
#  'Winter',
#  'Winter',
#  'Summer',
#  'Spring',
#  'Summer',
#  'Summer',
#  'Spring',
#  'Spring',
#  'Fall',
#  'Fall',
#  'Spring',
#  'Fall',
#  'Fall',
#  'Spring',
#  'Winter',
#  'Fall',
#  'Fall',
#  'Summer',
#  'Spring',
#  'Spring',
#  'Winter',
#  'Spring',
#  'Spring',
#  'Fall',
#  'Winter',
#  'Fall',
#  'Winter',
#  'Winter',
#  'Fall',
#  'Summer',
#  'Spring',
#  'Summer',
#  'Summer',
#  'Spring',
#  'Winter',
#  'Spring',
#  'Summer',
#  'Winter',
#  'Fall',
#  'Winter',
#  'Winter',
#  'Spring',
#  'Spring',
#  'Fall',
#  'Spring',
#  'Winter',
#  'Fall',
#  'Summer',
#  'Spring',
#  'Summer',
#  'Fall',
#  'Winter',
#  'Winter',
#  'Spring',
#  'Fall',
#  'Summer',
#  'Spring',
#  'Fall',
#  'Summer',
#  'Fall',
#  'Fall',
#  'Spring',
#  'Summer',
#  'Winter',
#  'Summer',
#  'Winter',
#  'Fall',
#  'Winter',
#  'Fall',
#  'Winter',
#  'Fall',
#  'Winter',
#  'Winter',
#  'Summer',
#  'Winter',
#  'Winter',
#  'Summer',
#  'Fall',
#  'Fall',
#  'Winter',
#  'Spring',
#  'Winter',
#  'Winter',
#  'Spring',
#  'Fall',
#  'Summer',
#  'Summer',
#  'Summer',
#  'Fall',
#  'Summer',
#  'Fall',
#  'Summer',
#  'Winter',
#  'Spring',
#  'Fall',
#  'Summer',
#  'Winter',
#  'Summer',
#  'Summer',
#  'Winter',
#  'Fall',
#  'Winter',
#  'Spring',
#  'Fall',
#  'Summer',
#  'Summer',
#  'Fall',
#  'Spring',
#  'Fall',
#  'Winter',
#  'Fall',
#  'Summer',
#  'Summer',
#  'Spring',
#  'Spring',
#  'Summer',
#  'Winter',
#  'Spring',
#  'Winter',
#  'Fall',
#  'Fall',
#  'Fall',
#  'Summer',
#  'Winter',
#  'Fall',
#  'Fall',
#  'Spring',
#  'Summer',
#  'Winter',
#  'Winter',
#  'Spring',
#  'Winter',
#  'Fall',
#  'Summer',
#  'Winter',
#  'Summer',
#  'Spring',
#  'Fall',
#  'Spring',
#  'Winter',
#  'Spring',
#  'Fall',
#  'Summer',
#  'Summer',
#  'Fall',
#  'Winter',
#  'Summer',
#  'Summer',
#  'Winter',
#  'Fall',
#  'Summer',
#  'Summer',
#  'Summer',
#  'Spring',
#  'Fall',
#  'Spring',
#  'Fall',
#  'Summer',
#  'Winter',
#  'Winter',
#  'Winter',
#  'Spring',
#  'Spring',
#  'Winter',
#  'Spring',
#  'Spring',
#  'Fall',
#  'Winter',
#  'Fall',
#  'Winter',
#  'Fall',
#  'Fall',
#  'Spring',
#  'Summer',
#  'Summer',
#  'Winter',
#  'Summer',
#  'Summer',
#  'Winter',
#  'Fall',
#  'Fall',
#  'Fall',
#  'Fall',
#  'Spring',
#  'Summer',
#  'Winter',
#  'Summer',
#  'Winter',
#  'Fall',
#  'Fall',
#  'Fall',
#  'Fall',
#  'Summer',
#  'Spring',
#  'Winter',
#  'Summer',
#  'Spring',
#  'Winter',
#  'Fall',
#  'Spring',
#  'Fall',
#  'Winter',
#  'Summer',
#  'Fall',
#  'Fall',
#  'Winter',
#  'Fall',
#  'Fall',
#  'Winter',
#  'Summer',
#  'Winter',
#  'Summer',
#  'Spring',
#  'Fall',
#  'Summer',
#  'Winter',
#  'Winter',
#  'Winter',
#  'Spring',
#  'Fall',
#  'Winter',
#  'Winter',
#  'Fall',
#  'Summer',
#  'Summer',
#  'Fall',
#  'Winter',
#  'Fall',
#  'Winter',
#  'Summer',
#  'Winter',
#  'Winter',
#  'Winter',
#  'Summer',
#  'Fall',
#  'Summer',
#  'Summer',
#  'Spring',
#  'Spring',
#  'Spring',
#  'Winter',
#  'Summer',
#  'Spring',
#  'Spring',
#  'Spring',
#  'Spring',
#  'Winter',
#  'Fall',
#  'Summer',
#  'Spring',
#  'Winter',
#  'Fall',
#  'Summer',
#  'Spring',
#  'Summer',
#  'Winter',
#  'Spring',
#  'Spring',
#  'Fall',
#  'Fall',
#  'Winter',
#  'Winter',
#  'Fall',
#  'Fall',
#  'Spring',
#  'Spring',
#  'Winter',
#  'Summer',
#  'Spring',
#  'Spring',
#  'Fall',
#  'Fall',
#  'Fall',
#  'Fall',
#  'Spring',
#  'Fall',
#  'Summer',
#  'Winter',
#  'Spring',
#  'Fall',
#  'Winter',
#  'Fall',
#  'Spring',
#  'Spring',
#  'Fall',
#  'Winter',
#  'Fall',
#  'Summer',
#  'Summer',
#  'Fall',
#  'Winter',
#  'Fall',
#  'Fall',
#  'Fall',
#  'Spring',
#  'Fall',
#  'Spring',
#  'Winter',
#  'Fall',
#  'Winter',
#  'Fall',
#  'Fall',
#  'Fall',
#  'Fall',
#  'Fall',
#  'Winter',
#  'Summer',
#  'Summer',
#  'Fall',
#  'Fall',
#  'Fall',
#  'Spring',
#  'Winter',
#  'Spring',
#  'Summer',
#  'Winter',
#  'Fall',
#  'Summer',
#  'Winter',
#  'Summer',
#  'Spring',
#  'Fall',
#  'Fall',
#  'Summer',
#  'Winter',
#  'Fall',
#  'Fall',
#  'Summer',
#  'Summer',
#  'Spring',
#  'Fall',
#  'Summer',
#  'Winter',
#  'Spring',
#  'Fall',
#  'Summer',
#  'Fall',
#  'Summer',
#  'Spring',
#  'Spring',
#  'Summer',
#  'Spring',
#  'Spring',
#  'Summer',
#  'Fall',
#  'Spring',
#  'Summer',
#  'Winter',
#  'Fall',
#  'Summer',
#  'Summer',
#  'Winter',
#  'Spring',
#  'Winter',
#  'Summer',
#  'Summer',
#  'Fall',
#  'Summer',
#  'Fall',
#  'Fall',
#  'Summer',
#  'Fall',
#  'Spring',
#  'Summer',
#  'Fall',
#  'Fall',
#  'Spring',
#  'Winter',
#  'Fall',
#  'Fall',
#  'Fall',
#  'Fall',
#  'Winter',
#  'Fall',
#  'Summer',
#  'Summer',
#  'Summer',
#  'Spring',
#  'Spring',
#  'Fall',
#  'Spring',
#  'Fall',
#  'Summer',
#  'Summer',
#  'Summer',
#  'Summer',
#  'Spring',
#  'Summer',
#  'Fall',
#  'Spring',
#  'Spring',
#  'Fall',
#  'Fall',
#  'Summer',
#  'Spring',
#  'Summer',
#  'Winter',
#  'Spring',
#  'Summer',
#  'Spring',
#  'Summer',
#  'Summer',
#  'Summer',
#  'Fall',
#  'Summer',
#  'Winter',
#  'Summer',
#  'Winter',
#  'Summer',
#  'Fall',
#  'Summer',
#  'Fall',
#  'Fall',
#  'Fall',
#  'Spring',
#  'Fall',
#  'Fall',
#  'Summer',
#  'Spring',
#  'Summer',
#  'Winter',
#  'Summer',
#  'Spring',
#  'Fall',
#  'Summer',
#  'Summer',
#  'Winter',
#  'Spring',
#  'Spring',
#  'Spring',
#  'Summer',
#  'Summer',
#  'Winter',
#  'Fall',
#  'Summer',
#  'Spring',
#  'Winter',
#  'Summer',
#  'Winter',
#  'Summer',
#  'Summer',
#  'Winter',
#  'Fall',
#  'Spring',
#  'Summer',
#  'Winter',
#  'Spring',
#  'Fall',
#  'Summer',
#  'Winter',
#  'Summer',
#  'Fall',
#  'Winter',
#  'Fall',
#  'Fall',
#  'Fall',
#  'Spring',
#  'Fall',
#  'Fall',
#  'Fall',
#  'Winter',
#  'Winter',
#  'Winter',
#  'Spring',
#  'Winter',
#  'Spring',
#  'Summer',
#  'Summer',
#  'Fall',
#  'Summer',
#  'Winter',
#  'Fall',
#  'Fall',
#  'Fall',
#  'Summer',
#  'Winter',
#  'Winter',
#  'Spring',
#  'Winter',
#  'Winter',
#  'Summer',
#  'Fall',
#  'Summer',
#  'Winter',
#  'Winter',
#  'Summer',
#  'Summer',
#  'Fall',
#  'Winter',
#  'Fall',
#  'Summer',
#  'Winter',
#  'Summer',
#  'Fall',
#  'Fall',
#  'Fall',
#  'Spring',
#  'Fall',
#  'Spring',
#  'Spring',
#  'Fall',
#  'Winter',
#  'Fall',
#  'Fall',
#  'Summer',
#  'Fall',
#  'Fall',
#  'Winter',
#  'Winter',
#  'Spring',
#  'Spring',
#  'Winter',
#  'Winter',
#  'Spring',
#  'Spring',
#  'Fall',
#  'Fall',
#  'Summer',
#  'Spring',
#  'Winter',
#  'Summer',
#  'Winter',
#  'Spring',
#  'Spring',
#  'Spring',
#  'Fall',
#  'Spring',
#  'Winter',
#  'Fall',
#  'Winter',
#  'Spring',
#  'Winter',
#  'Fall',
#  'Fall',
#  'Spring',
#  'Fall',
#  'Fall',
#  'Fall',
#  'Summer',
#  'Winter',
#  'Fall',
#  'Spring',
#  'Spring',
#  'Summer',
#  'Spring',
#  'Summer',
#  'Fall',
#  'Winter',
#  'Winter',
#  'Spring',
#  'Fall',
#  'Summer',
#  'Fall',
#  'Summer',
#  'Spring',
#  'Summer',
#  'Winter',
#  'Summer',
#  'Winter',
#  'Winter',
#  'Summer',
#  'Spring',
#  'Spring',
#  'Fall',
#  'Spring',
#  'Spring',
#  'Fall',
#  'Winter',
#  'Winter',
#  'Summer',
#  'Winter',
#  'Fall',
#  'Winter',
#  'Fall',
#  'Summer',
#  'Summer',
#  'Spring',
#  'Winter',
#  'Fall',
#  'Winter',
#  'Summer',
#  'Fall',
#  'Fall',
#  'Fall',
#  'Winter',
#  'Fall',
#  'Spring',
#  'Fall',
#  'Summer',
#  'Summer',
#  'Summer',
#  'Spring',
#  'Fall',
#  'Summer',
#  'Summer',
#  'Fall',
#  'Spring',
#  'Summer',
#  'Fall',
#  'Summer',
#  'Summer',
#  'Fall',
#  'Winter',
#  'Fall',
#  'Fall',
#  ...]
